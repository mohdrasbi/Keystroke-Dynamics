# %%
from functions import *

# %%
path_train = 'test_data/user_{}/raw_data/*'
users = [0,1,2,3,4,5]

# %%
for user in users:
    user_path = path_train.format(user)
    for file in glob.glob(user_path):
        df = pd.read_csv(file)
        ExtractFeatures(df, user, 'test_data')

# %%
pd.read_csv('test_data/user_5/final_data/1.csv')
# Out:
#      ri_left  ri_right   ri_same     ri_ht   rm_left  rm_right  rm_same  \
# 0   0.110951  0.225331  0.182628  0.154831  0.384065  0.202115  0.17672
# 1   0.142815  0.204547  0.195840  0.157809  0.588018  0.371241  0.17672
# 2   0.187640  0.343219  0.195840  0.226535  0.316558  0.262170  0.17672
# 3   0.291056  0.384754  0.195840  0.299574  0.204781  0.262170  0.17672
# 4   0.190776  0.213590  0.262193  0.176138  0.469850  0.187454  0.17672
# 5   0.135646  0.209870  0.181464  0.162685  0.576625  0.181901  0.17672
# 6   0.204418  0.237840  0.138736  0.212892  0.825809  0.304692  0.17672
# 7   0.137886  0.218785  0.195840  0.162657  0.199048  0.553507  0.17672
# 8   0.127884  0.205151  0.172296  0.158772  0.198139  0.262170  0.17672
# 9   0.135407  0.216244  0.202603  0.158383  0.192627  0.313922  0.17672
# 10  0.288356  0.168984  0.195840  0.238617  0.162721  0.184156  0.17672
# 11  0.261243  0.344364  0.162603  0.243068  0.620937  0.191613  0.17672
# ...
